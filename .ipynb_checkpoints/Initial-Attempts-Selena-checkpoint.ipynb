# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Load data
import pandas as pd
data = pd.read_csv("data.csv",header = 0)
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#Clean up data
data = data.drop('id', 1)
data = data.drop("Unnamed: 32",1)
#In diagnosis, map M to 1 (positive) and B to 0 (negative)
data['diagnosis'] = data['diagnosis'].map({'M' : 1, 'B' : 0})
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
#Organizing data in numpy arrays
np.set_printoptions(suppress=True) #Scientific notation is annoying...
split_index = int(data.shape[0]*0.8) #Splitting test (20%) and train(80%) at this index
np_data = np.array(data, dtype=float)
#Features
x = np_data[:,1:31]
x_train = x[0:split_index,:]
x_test = x[split_index:,:]
#Target values
y = np_data[:,0]
y_train = y[:split_index]
y_test = y[split_index:]

# %%
#Function that takes classifier as paramater and does all that werk
def fit_model(model, param_grid, x_test, x_train, y_test, y_train):
#     #First fit the params
#     grid = GridSearchCV(model, param_grid, cv = 10, scoring = "accuracy")
#     grid.fit(x_train, y_train)
#     grid_mean_scores =[result.mean_validation_score for result in grid.grid_scores_]
#     for val in param_grid.values():
        
#     plt.plot(k_range,grid_mean_scores)
#     plt.xlabel("K Values")
#     plt.ylabel("Accuracy")
#     print grid.best_score_
#     print grid.best_params_
#     best_k = grid.best_params_['n_neighbors']

#     neigh = KNeighborsClassifier(n_neighbors=best_k)
#     neigh.fit(x_train, y_train)
#     #Evaluation
#     print "Accuracy: ", neigh.score(x_test,y_test)
#     confusion_knn = confusion_matrix(neigh.predict(x_test), y_test)
#     print confusion_knn

# %%
#k-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.grid_search import GridSearchCV 

k_range = range(1,100)
param_grid=dict(n_neighbors=k_range)
grid =GridSearchCV(neigh,param_grid,cv=10,scoring="accuracy")
grid.fit(x_train,y_train)
grid_mean_scores =[result.mean_validation_score for result in grid.grid_scores_]
plt.plot(k_range,grid_mean_scores)
plt.xlabel("K Values")
plt.ylabel("Accuracy")
print grid.best_score_
print grid.best_params_
best_k = grid.best_params_['n_neighbors']

neigh = KNeighborsClassifier(n_neighbors=best_k)
neigh.fit(x_train, y_train)
#Evaluation
print "Accuracy: ", neigh.score(x_test,y_test)
confusion_knn = confusion_matrix(neigh.predict(x_test), y_test)
print confusion_knn
# Out:
# 0.940659340659
# {'n_neighbors': 13}
# Accuracy:  0.947368421053
# [[83  1]
#  [ 5 25]]

# %%
#Choose N

labelfont = {
        'family' : 'sans-serif',  # (cursive, fantasy, monospace, serif)
        'color'  : 'black',       # html hex or colour name
        'weight' : 'normal',      # (normal, bold, bolder, lighter)
        'size'   : 14,            # default value:12
        }

titlefont = {
        'family' : 'serif',
        'color'  : 'black',
        'weight' : 'bold',
        'size'   : 16,
        }

# how recalls fluctuate with N
recall_list=[]
for i in range(1,100):
    neigh = KNeighborsClassifier(n_neighbors=i)
    neigh.fit(x_train, y_train)
    newrecall=recall_score(y_test, neigh.predict(x_test))
    recall_list.append(newrecall)
plt.plot(range(1,100),recall_list )

plt.title('Recall Function', fontdict=titlefont) 
plt.xlabel('N', fontdict=labelfont)
plt.ylabel('Recall(%)', fontdict=labelfont)

plt.show()

# Accuracy fluctuates with N
score_list=[]
for i in range(1,100):
    neigh = KNeighborsClassifier(n_neighbors=i)
    neigh.fit(x_train, y_train)
    newscore=neigh.score(x_test,y_test)
    score_list.append(newscore)
plt.plot(range(1,100),score_list )

plt.title('Accuracy Function', fontdict=titlefont) 
plt.xlabel('N', fontdict=labelfont)
plt.ylabel('Accuracy(%)', fontdict=labelfont)

plt.show()

#Precision fluctuates with N 
precision_list=[]
for i in range(1,100):
    neigh = KNeighborsClassifier(n_neighbors=i)
    neigh.fit(x_train, y_train)
    newprecision=precision_score(y_test, neigh.predict(x_test))
    precision_list.append(newprecision)
plt.plot(range(1,100),precision_list )

plt.title('Precision Function', fontdict=titlefont) 
plt.xlabel('N', fontdict=labelfont)
plt.ylabel('Precision(%)', fontdict=labelfont)

plt.show()

# Assessing the classifier 
neigh = KNeighborsClassifier(n_neighbors=50)
neigh.fit(x_train, y_train)
confusion_knn = confusion_matrix(neigh.predict(x_test), y_test)
print confusion_knn
# Out:
# [[85  2]
#  [ 3 24]]

# %%
#Logistic Regression
lr = LogisticRegression()
lr.fit(x_train,y_train)
#Evaluation
print lr.score(x_test,y_test)
print recall_score(y_test, lr.predict(x_test))
print precision_score(y_test, lr.predict(x_test))
confusion_lr = confusion_matrix(lr.predict(x_test), y_test)
print confusion_lr
print lr.get_params()
# Out:
# 0.929824561404
# 0.961538461538
# 0.78125
# [[81  1]
#  [ 7 25]]
# {'warm_start': False, 'C': 1.0, 'n_jobs': 1, 'verbose': 0, 'intercept_scaling': 1, 'fit_intercept': True, 'max_iter': 100, 'penalty': 'l2', 'multi_class': 'ovr', 'random_state': None, 'dual': False, 'tol': 0.0001, 'solver': 'liblinear', 'class_weight': None}

# %%
# #NEURAL NETS not available in this version of sklearn, gotta install...
# #http://stackoverflow.com/questions/34016238/sklearn-import-mlpclassifier-fails
# #Attempting Neural Networks
# #Sensitive to feature scaling...
# from sklearn.neural_network import MLPClassifier
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# scaler.fit(x_train)
# scaled_x_train = scaler.transform(x_train)
# scaled_x_test = scaler.transform(x_test)

# #"Empirically, we observed that L-BFGS converges faster and with better solutions on small datasets." - sklearn
# net = MLPClassifier(solver="lbfgs", alpha=1e-5, hidden_later_sizes=(5,2), random_state=1)
# net.fit(x_train, y_train)

# %%
#Random Forest
#info: http://scikit-learn.org/stable/modules/ensemble.html
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=10)
forest = forest.fit(x_train, y_train)
print forest.score(x_test, y_test)
cm = confusion_matrix(forest.predict(x_test), y_test)


print "TN: "
print cm[0][0]
print "FN: "
print cm[1][0]
print "TP: "
print cm[1][1]
print "FP: "
print cm[0][1]
print forest.get_params()
# Out:
# 1.0
# TN:
# 88
# FN:
# 0
# TP:
# 26
# FP:
# 0
# {'warm_start': False, 'oob_score': False, 'n_jobs': 1, 'verbose': 0, 'max_leaf_nodes': None, 'bootstrap': True, 'min_samples_leaf': 1, 'n_estimators': 10, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'criterion': 'gini', 'random_state': None, 'max_features': 'auto', 'max_depth': None, 'class_weight': None}

# %%
#Graph???
from sklearn.decomposition import PCA
pca = PCA(n_components=2).fit(x_train)
pca_2d = pca.transform(x_train)
import pylab as pl
for i in range(0, pca_2d.shape[0]):
    if y_train[i] == 0:
        c1 = pl.scatter(pca_2d[i,0],pca_2d[i,1],c=0, color='red')
    elif y_train[i] == 1:
        c2 = pl.scatter(pca_2d[i,0],pca_2d[i,1],c=1, color='blue')
pl.show()
